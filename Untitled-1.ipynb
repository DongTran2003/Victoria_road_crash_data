# %% [markdown]
# I. Requirement

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import time
import numpy as np

# %%
accidents_df = pd.read_csv("accident.csv")
vehicles_df = pd.read_csv("vehicle.csv")
person_df = pd.read_csv("person.csv")
location_df = pd.read_csv("accident_location.csv")
node_df = pd.read_csv("node.csv")

# %% [markdown]
# II. Data Exploration

# %%
accidents_df.columns
# Out:
# Index(['ACCIDENT_NO', 'ACCIDENT_DATE', 'ACCIDENT_TIME', 'ACCIDENT_TYPE',
#        'ACCIDENT_TYPE_DESC', 'DAY_OF_WEEK', 'DAY_WEEK_DESC', 'DCA_CODE',
#        'DCA_DESC', 'LIGHT_CONDITION', 'NODE_ID', 'NO_OF_VEHICLES',
#        'NO_PERSONS_KILLED', 'NO_PERSONS_INJ_2', 'NO_PERSONS_INJ_3',
#        'NO_PERSONS_NOT_INJ', 'NO_PERSONS', 'POLICE_ATTEND', 'ROAD_GEOMETRY',
#        'ROAD_GEOMETRY_DESC', 'SEVERITY', 'SPEED_ZONE', 'RMA'],
#       dtype='object')

# %%
vehicles_df.columns
# Out:
# Index(['ACCIDENT_NO', 'VEHICLE_ID', 'VEHICLE_YEAR_MANUF', 'VEHICLE_DCA_CODE',
#        'INITIAL_DIRECTION', 'ROAD_SURFACE_TYPE', 'ROAD_SURFACE_TYPE_DESC',
#        'REG_STATE', 'VEHICLE_BODY_STYLE', 'VEHICLE_MAKE', 'VEHICLE_MODEL',
#        'VEHICLE_POWER', 'VEHICLE_TYPE', 'VEHICLE_TYPE_DESC', 'VEHICLE_WEIGHT',
#        'CONSTRUCTION_TYPE', 'FUEL_TYPE', 'NO_OF_WHEELS', 'NO_OF_CYLINDERS',
#        'SEATING_CAPACITY', 'TARE_WEIGHT', 'TOTAL_NO_OCCUPANTS',
#        'CARRY_CAPACITY', 'CUBIC_CAPACITY', 'FINAL_DIRECTION', 'DRIVER_INTENT',
#        'VEHICLE_MOVEMENT', 'TRAILER_TYPE', 'VEHICLE_COLOUR_1',
#        'VEHICLE_COLOUR_2', 'CAUGHT_FIRE', 'INITIAL_IMPACT', 'LAMPS',
#        'LEVEL_OF_DAMAGE', 'TOWED_AWAY_FLAG', 'TRAFFIC_CONTROL',
#        'TRAFFIC_CONTROL_DESC'],
#       dtype='object')

# %%
person_df.columns
# Out:
# Index(['ACCIDENT_NO', 'PERSON_ID', 'VEHICLE_ID', 'SEX', 'AGE_GROUP',
#        'INJ_LEVEL', 'INJ_LEVEL_DESC', 'SEATING_POSITION', 'HELMET_BELT_WORN',
#        'ROAD_USER_TYPE', 'ROAD_USER_TYPE_DESC', 'LICENCE_STATE',
#        'TAKEN_HOSPITAL', 'EJECTED_CODE'],
#       dtype='object')

# %%
location_df.columns
# Out:
# Index(['ACCIDENT_NO', 'NODE_ID', 'ROAD_ROUTE_1', 'ROAD_NAME', 'ROAD_TYPE',
#        'ROAD_NAME_INT', 'ROAD_TYPE_INT', 'DISTANCE_LOCATION',
#        'DIRECTION_LOCATION'],
#       dtype='object')

# %%
node_df.columns
# Out:
# Index(['_id', 'ACCIDENT_NO', 'NODE_ID', 'NODE_TYPE', 'AMG_X', 'AMG_Y',
#        'LGA_NAME', 'LGA NAME ALL', 'DEG_URBAN_NAME', 'LATITUDE', 'LONGITUDE',
#        'POSTCODE_CRASH'],
#       dtype='object')

# %%
accidents = accidents_df[['ACCIDENT_NO', 'ACCIDENT_DATE', 'ACCIDENT_TIME',
       'ACCIDENT_TYPE_DESC', 'DAY_WEEK_DESC', 'LIGHT_CONDITION', 'NO_OF_VEHICLES',
       'NO_PERSONS_KILLED', 'NO_PERSONS_INJ_2', 'NO_PERSONS_INJ_3',
       'NO_PERSONS_NOT_INJ', 'NO_PERSONS', 'POLICE_ATTEND',
       'ROAD_GEOMETRY_DESC', 'SEVERITY', 'SPEED_ZONE']]

vehicles = vehicles_df[['ACCIDENT_NO', 'VEHICLE_ID', 'VEHICLE_YEAR_MANUF',
       'VEHICLE_MAKE', 'VEHICLE_MODEL',
       'VEHICLE_POWER', 'VEHICLE_TYPE_DESC', 'VEHICLE_WEIGHT',
       'SEATING_CAPACITY', 'TARE_WEIGHT', 'TOTAL_NO_OCCUPANTS',
       'CARRY_CAPACITY', 'CUBIC_CAPACITY',
       'LAMPS', 'LEVEL_OF_DAMAGE']]

person = person_df[['ACCIDENT_NO', 'PERSON_ID', 'SEX', 'AGE_GROUP',
       'INJ_LEVEL_DESC', 'SEATING_POSITION', 'HELMET_BELT_WORN',
       'ROAD_USER_TYPE_DESC', 'TAKEN_HOSPITAL']]

location = location_df[['ACCIDENT_NO', 'ROAD_NAME', 'ROAD_TYPE',
       'ROAD_NAME_INT', 'ROAD_TYPE_INT']]

node = node_df[['ACCIDENT_NO', 'AMG_X', 'AMG_Y',
       'LGA_NAME', 'LGA NAME ALL', 'DEG_URBAN_NAME', 'LATITUDE', 'LONGITUDE',
       'POSTCODE_CRASH']]

# %%
accidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179877 entries, 0 to 179876
# Data columns (total 16 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ACCIDENT_NO         179877 non-null  object
#  1   ACCIDENT_DATE       179877 non-null  object
#  2   ACCIDENT_TIME       179877 non-null  object
#  3   ACCIDENT_TYPE_DESC  179877 non-null  object
#  4   DAY_WEEK_DESC       179877 non-null  object
#  5   LIGHT_CONDITION     179877 non-null  int64
#  6   NO_OF_VEHICLES      179877 non-null  int64
#  7   NO_PERSONS_KILLED   179877 non-null  int64
#  8   NO_PERSONS_INJ_2    179877 non-null  int64
#  9   NO_PERSONS_INJ_3    179877 non-null  int64
#  10  NO_PERSONS_NOT_INJ  179877 non-null  int64
#  11  NO_PERSONS          179877 non-null  int64
#  12  POLICE_ATTEND       179877 non-null  int64
#  13  ROAD_GEOMETRY_DESC  179877 non-null  object
#  14  SEVERITY            179877 non-null  int64
#  15  SPEED_ZONE          179877 non-null  int64
# dtypes: int64(10), object(6)
# memory usage: 22.0+ MB

# %%
accidents["SEVERITY"] = accidents["SEVERITY"].astype(object) 
accidents["LIGHT_CONDITION"] = accidents["LIGHT_CONDITION"].astype(object)
accidents["SPEED_ZONE"] = accidents["SPEED_ZONE"].astype(object)
accidents["POLICE_ATTEND"] = accidents["POLICE_ATTEND"].astype(object)
# Out:
# C:\Users\phucd\AppData\Local\Temp\ipykernel_20804\1193437860.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accidents["SEVERITY"] = accidents["SEVERITY"].astype(object)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_20804\1193437860.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accidents["LIGHT_CONDITION"] = accidents["LIGHT_CONDITION"].astype(object)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_20804\1193437860.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accidents["SPEED_ZONE"] = accidents["SPEED_ZONE"].astype(object)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_20804\1193437860.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accidents["POLICE_ATTEND"] = accidents["POLICE_ATTEND"].astype(object)

# %%
accidents["ACCIDENT_DATE"] = pd.to_datetime(accidents["ACCIDENT_DATE"]) #set ACCIDENT_DATE to datetime datatype
accidents["ACCIDENT_TIME"] = pd.to_datetime(accidents["ACCIDENT_TIME"]).dt.time #set ACCIDENT_TIME to datetime with Hour datatype
# Out:
# C:\Users\phucd\AppData\Local\Temp\ipykernel_20804\3576189223.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accidents["ACCIDENT_DATE"] = pd.to_datetime(accidents["ACCIDENT_DATE"]) #set ACCIDENT_DATE to datetime datatype
# C:\Users\phucd\AppData\Local\Temp\ipykernel_20804\3576189223.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   accidents["ACCIDENT_TIME"] = pd.to_datetime(accidents["ACCIDENT_TIME"]).dt.time #set ACCIDENT_TIME to datetime with Hour datatype
# C:\Users\phucd\AppData\Local\Temp\ipykernel_20804\3576189223.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accidents["ACCIDENT_TIME"] = pd.to_datetime(accidents["ACCIDENT_TIME"]).dt.time #set ACCIDENT_TIME to datetime with Hour datatype

# %%
accidents.head()
# Out:
#     ACCIDENT_NO ACCIDENT_DATE ACCIDENT_TIME             ACCIDENT_TYPE_DESC  \
# 0  T20120000009    2012-01-01      02:25:00  Collision with a fixed object
# 1  T20120000012    2012-01-01      02:00:00         Collision with vehicle
# 2  T20120000013    2012-01-01      03:35:00         Collision with vehicle
# 3  T20120000018    2012-01-01      05:15:00  Collision with a fixed object
# 4  T20120000021    2012-01-01      07:30:00  Collision with a fixed object
#
#   DAY_WEEK_DESC  LIGHT_CONDITION  NO_OF_VEHICLES  NO_PERSONS_KILLED  \
# 0        Sunday                5               1                  0
# 1        Sunday                3               2                  0
# 2        Sunday                3               2                  0
# 3        Sunday                5               1                  0
# 4        Sunday                1               1                  0
#
#    NO_PERSONS_INJ_2  NO_PERSONS_INJ_3  NO_PERSONS_NOT_INJ  NO_PERSONS  \
# 0                 0                 2                   0           2
# 1                 1                 0                   2           3
# 2                 1                 0                   0           1
# 3                 0                 1                   0           1
# 4                 0                 2                   1           3
#
#    POLICE_ATTEND   ROAD_GEOMETRY_DESC  SEVERITY  SPEED_ZONE
# 0              1  Not at intersection         3         100
# 1              1   Cross intersection         2          80
# 2              1       T intersection         2          60
# 3              1   Cross intersection         3         100
# 4              1  Not at intersection         3          50

# %%
accidents.isnull().sum()
# Out:
# ACCIDENT_NO           0
# ACCIDENT_DATE         0
# ACCIDENT_TIME         0
# ACCIDENT_TYPE_DESC    0
# DAY_WEEK_DESC         0
# LIGHT_CONDITION       0
# NO_OF_VEHICLES        0
# NO_PERSONS_KILLED     0
# NO_PERSONS_INJ_2      0
# NO_PERSONS_INJ_3      0
# NO_PERSONS_NOT_INJ    0
# NO_PERSONS            0
# POLICE_ATTEND         0
# ROAD_GEOMETRY_DESC    0
# SEVERITY              0
# SPEED_ZONE            0
# dtype: int64

# %%
accidents.duplicated().sum()
# Out:
# np.int64(0)

# %%
accidents[['ACCIDENT_DATE', 'ACCIDENT_TIME', 'ACCIDENT_TYPE_DESC',
       'DAY_WEEK_DESC', 'LIGHT_CONDITION', 'NO_OF_VEHICLES',
       'NO_PERSONS_KILLED', 'NO_PERSONS_INJ_2', 'NO_PERSONS_INJ_3',
       'NO_PERSONS_NOT_INJ', 'NO_PERSONS', 'POLICE_ATTEND',
       'ROAD_GEOMETRY_DESC', 'SEVERITY', 'SPEED_ZONE']].duplicated().sum()
# Out:
# np.int64(74)

# %%
accidents_categorical = []
accidents_numerical = []

for i in accidents:
    if accidents[i].dtype == 'O':
        accidents_categorical.append(i)

for i in accidents:
    if i not in accidents_categorical:
        accidents_numerical.append(i)

print(accidents_categorical)
print(accidents_numerical)
# Out:
# ['ACCIDENT_NO', 'ACCIDENT_TIME', 'ACCIDENT_TYPE_DESC', 'DAY_WEEK_DESC', 'LIGHT_CONDITION', 'POLICE_ATTEND', 'ROAD_GEOMETRY_DESC', 'SEVERITY', 'SPEED_ZONE']
# ['ACCIDENT_DATE', 'NO_OF_VEHICLES', 'NO_PERSONS_KILLED', 'NO_PERSONS_INJ_2', 'NO_PERSONS_INJ_3', 'NO_PERSONS_NOT_INJ', 'NO_PERSONS']

# %%
accidents[accidents_categorical].describe()
# Out:
#          ACCIDENT_NO ACCIDENT_TIME      ACCIDENT_TYPE_DESC DAY_WEEK_DESC  \
# count         179877        179877                  179877        179877
# unique        179877          1440                       9             7
# top     T20240019374      16:00:00  Collision with vehicle        Friday
# freq               1          2612                  116812         28429
#
#         LIGHT_CONDITION  POLICE_ATTEND   ROAD_GEOMETRY_DESC  SEVERITY  \
# count            179877         179877               179877    179877
# unique                7              3                    9         4
# top                   1              1  Not at intersection         3
# freq             120042         132989                93047    112235
#
#         SPEED_ZONE
# count       179877
# unique          13
# top             60
# freq         59172

# %%
accidents[accidents_numerical].describe()
# Out:
#                        ACCIDENT_DATE  NO_OF_VEHICLES  NO_PERSONS_KILLED  \
# count                         179877   179877.000000      179877.000000
# mean   2018-04-21 11:31:47.563501568        1.823807           0.017779
# min              2012-01-01 00:00:00        0.000000           0.000000
# 25%              2015-03-01 00:00:00        1.000000           0.000000
# 50%              2018-03-16 00:00:00        2.000000           0.000000
# 75%              2021-07-14 00:00:00        2.000000           0.000000
# max              2024-07-31 00:00:00       21.000000           5.000000
# std                              NaN        0.747419           0.143869
#
#        NO_PERSONS_INJ_2  NO_PERSONS_INJ_3  NO_PERSONS_NOT_INJ     NO_PERSONS
# count     179877.000000     179877.000000       179877.000000  179877.000000
# mean           0.417680          0.867393            1.033868       2.336719
# min            0.000000          0.000000            0.000000       1.000000
# 25%            0.000000          0.000000            0.000000       2.000000
# 50%            0.000000          1.000000            1.000000       2.000000
# 75%            1.000000          1.000000            1.000000       3.000000
# max           16.000000         43.000000           94.000000      97.000000
# std            0.624173          0.792043            1.237860       1.465788

# %%
fig, axes = plt.subplots(nrows=5, ncols=2, figsize=(15, 15))  # adjust rows/cols as needed
axes = axes.flatten()  # flatten to 1D array for easy looping

# Plot each column as bar chart
for i, col in enumerate(accidents_numerical):
    sns.boxplot(data=accidents[accidents_numerical], y=col, ax=axes[i])
    axes[i].set_title(f"{col}")
    axes[i].set_xlabel("Value")
    axes[i].set_ylabel("Count")

# Hide any unused axes if columns < subplot cells
for j in range(len(accidents_numerical), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(nrows=7, ncols=2, figsize=(15, 35))  # adjust rows/cols as needed
axes = axes.flatten()  # flatten to 1D array for easy looping

columns = ['ACCIDENT_TYPE_DESC',
       'DAY_WEEK_DESC', 'LIGHT_CONDITION', 'NO_OF_VEHICLES',
       'NO_PERSONS_KILLED', 'NO_PERSONS_INJ_2', 'NO_PERSONS_INJ_3',
       'NO_PERSONS_NOT_INJ', 'NO_PERSONS', 'POLICE_ATTEND',
       'ROAD_GEOMETRY_DESC', 'SEVERITY', 'SPEED_ZONE']
# Plot each column as bar chart
for i, col in enumerate(columns):
    accidents[col].value_counts().sort_index().plot.bar(ax=axes[i])
    axes[i].set_title(f"{col}")
    axes[i].set_xlabel("Value")
    axes[i].set_ylabel("Count")

# Hide any unused axes if columns < subplot cells
for j in range(len(columns), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
numerical_col = ['LIGHT_CONDITION', 'NO_OF_VEHICLES',
       'NO_PERSONS_KILLED', 'NO_PERSONS_INJ_2', 'NO_PERSONS_INJ_3',
       'NO_PERSONS_NOT_INJ', 'NO_PERSONS', 'POLICE_ATTEND', 'SEVERITY', 'SPEED_ZONE']
fig, ax = plt.subplots(figsize=(10,10))
cm = sns.heatmap(accidents[numerical_col].corr(), linewidths = .5, cmap="RdBu", annot=True, fmt='.1g', vmin=-1, vmax=1)

# %% [markdown]
# Next Dataset

# %%
vehicles.head()
# Out:
#     ACCIDENT_NO VEHICLE_ID  VEHICLE_YEAR_MANUF VEHICLE_MAKE VEHICLE_MODEL  \
# 0  T20120000009          A              1996.0       HOLDEN        ACCLAI
# 1  T20120000012          A              2002.0       HOLDEN        MONARO
# 2  T20120000012          B              1988.0       TOYOTA           NaN
# 3  T20120000013          A              1997.0       MITSUB         MAGNA
# 4  T20120000013          B              2010.0       TOYOTA           NaN
#
#    VEHICLE_POWER VEHICLE_TYPE_DESC  VEHICLE_WEIGHT  SEATING_CAPACITY  \
# 0            NaN               Car             NaN               5.0
# 1            NaN               Car             NaN               4.0
# 2            NaN               Car          1450.0               5.0
# 3            NaN               Car             NaN               5.0
# 4            NaN     Station Wagon             NaN               7.0
#
#    TARE_WEIGHT  TOTAL_NO_OCCUPANTS  CARRY_CAPACITY  CUBIC_CAPACITY  LAMPS  \
# 0       1350.0                 2.0             NaN             NaN    1.0
# 1       1600.0                 2.0             NaN             NaN    1.0
# 2       1150.0                 1.0           300.0             NaN    9.0
# 3       1300.0                 1.0             NaN             NaN    1.0
# 4       2250.0                 0.0             NaN             NaN    2.0
#
#    LEVEL_OF_DAMAGE
# 0                5
# 1                2
# 2                4
# 3                4
# 4                4

# %%
vehicles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 328057 entries, 0 to 328056
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ACCIDENT_NO         328057 non-null  object
#  1   VEHICLE_ID          328057 non-null  object
#  2   VEHICLE_YEAR_MANUF  321128 non-null  float64
#  3   VEHICLE_MAKE        309812 non-null  object
#  4   VEHICLE_MODEL       297334 non-null  object
#  5   VEHICLE_POWER       0 non-null       float64
#  6   VEHICLE_TYPE_DESC   328057 non-null  object
#  7   VEHICLE_WEIGHT      40982 non-null   float64
#  8   SEATING_CAPACITY    271661 non-null  float64
#  9   TARE_WEIGHT         316113 non-null  float64
#  10  TOTAL_NO_OCCUPANTS  328035 non-null  float64
#  11  CARRY_CAPACITY      40828 non-null   float64
#  12  CUBIC_CAPACITY      45409 non-null   float64
#  13  LAMPS               328056 non-null  float64
#  14  LEVEL_OF_DAMAGE     328057 non-null  int64
# dtypes: float64(9), int64(1), object(5)
# memory usage: 37.5+ MB

# %%
vehicles.isnull().sum()
# Out:
# ACCIDENT_NO                0
# VEHICLE_ID                 0
# VEHICLE_YEAR_MANUF      6929
# VEHICLE_MAKE           18245
# VEHICLE_MODEL          30723
# VEHICLE_POWER         328057
# VEHICLE_TYPE_DESC          0
# VEHICLE_WEIGHT        287075
# SEATING_CAPACITY       56396
# TARE_WEIGHT            11944
# TOTAL_NO_OCCUPANTS        22
# CARRY_CAPACITY        287229
# CUBIC_CAPACITY        282648
# LAMPS                      1
# LEVEL_OF_DAMAGE            0
# dtype: int64

# %%
(vehicles.isnull().sum() / len(vehicles)) * 100 # Check the percentage of missing values out of all records
# Out:
# ACCIDENT_NO             0.000000
# VEHICLE_ID              0.000000
# VEHICLE_YEAR_MANUF      2.112133
# VEHICLE_MAKE            5.561534
# VEHICLE_MODEL           9.365141
# VEHICLE_POWER         100.000000
# VEHICLE_TYPE_DESC       0.000000
# VEHICLE_WEIGHT         87.507659
# SEATING_CAPACITY       17.190915
# TARE_WEIGHT             3.640831
# TOTAL_NO_OCCUPANTS      0.006706
# CARRY_CAPACITY         87.554602
# CUBIC_CAPACITY         86.158198
# LAMPS                   0.000305
# LEVEL_OF_DAMAGE         0.000000
# dtype: float64

# %%
ax = round(((vehicles.isnull().sum() / len(vehicles)) * 100),3).plot.bar(figsize=(10,5))
ax.bar_label(ax.containers[0])
plt.show()

# %%
vehicles.drop(['VEHICLE_POWER', 'CUBIC_CAPACITY'], axis = 1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[495], line 1
# ----> 1 vehicles.drop(['VEHICLE_POWER', 'CUBIC_CAPACITY'], axis = 1, inplace=True)
#
# File c:\Users\phucd\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File c:\Users\phucd\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File c:\Users\phucd\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File c:\Users\phucd\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['VEHICLE_POWER', 'CUBIC_CAPACITY'] not found in axis"

# %%
vehicles['LAMPS'] = vehicles['LAMPS'].astype('O')
vehicles['LEVEL_OF_DAMAGE'] = vehicles['LEVEL_OF_DAMAGE'].astype('O')
# Out:
# C:\Users\phucd\AppData\Local\Temp\ipykernel_20804\2816087664.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['LAMPS'] = vehicles['LAMPS'].astype('O')
# C:\Users\phucd\AppData\Local\Temp\ipykernel_20804\2816087664.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['LEVEL_OF_DAMAGE'] = vehicles['LEVEL_OF_DAMAGE'].astype('O')

# %%
vehicles_categorical = []
vehicles_numerical = []

for i in vehicles.columns:
    if vehicles[i].dtype == 'O':
        vehicles_categorical.append(i)
    
for i in vehicles.columns:
    if i not in vehicles_categorical:
        vehicles_numerical.append(i)

print(vehicles_categorical)
print(vehicles_numerical)
# Out:
# ['ACCIDENT_NO', 'VEHICLE_ID', 'VEHICLE_MAKE', 'VEHICLE_MODEL', 'VEHICLE_TYPE_DESC', 'LAMPS', 'LEVEL_OF_DAMAGE']
# ['VEHICLE_YEAR_MANUF', 'VEHICLE_WEIGHT', 'SEATING_CAPACITY', 'TARE_WEIGHT', 'TOTAL_NO_OCCUPANTS', 'CARRY_CAPACITY']

# %%
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(15, 25))
axes = axes.flatten()

# Plot numerical columns
for i, col in enumerate(vehicles_numerical):
    sns.histplot(data=vehicles, x=col, ax=axes[i])
    axes[i].set_title(f"Distribution of {col}")
    axes[i].set_ylabel("Count")

# Plot categorical columns at the end
categorical_cols = ['LAMPS', 'LEVEL_OF_DAMAGE']

for j, cat_col in enumerate(categorical_cols, start=len(vehicles_numerical)):
    sns.countplot(data=vehicles, x=cat_col, ax=axes[j])
    axes[j].set_title(f"Count of {cat_col}")
    axes[j].set_ylabel("Count")

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(15, 15))  # adjust rows/cols as needed
axes = axes.flatten()  # flatten to 1D array for easy looping

# Plot each column as bar chart
for i, col in enumerate(vehicles_numerical):
    sns.boxplot(data=vehicles[vehicles_numerical], y=col, ax=axes[i], color="orange")
    axes[i].set_title(f"{col}")
    axes[i].set_xlabel("Value")
    axes[i].set_ylabel("Count")

# Hide any unused axes if columns < subplot cells
for j in range(len(vehicles_numerical), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
numerical_col = ['VEHICLE_YEAR_MANUF', 'VEHICLE_WEIGHT',
       'SEATING_CAPACITY', 'TARE_WEIGHT', 'TOTAL_NO_OCCUPANTS',
       'CARRY_CAPACITY', 'LAMPS', 'LEVEL_OF_DAMAGE']
fig, ax = plt.subplots(figsize=(10,10))
cm = sns.heatmap(vehicles[numerical_col].corr(), linewidths = .5, cmap="RdBu", annot=True, ax=ax, fmt='.1g', vmin=-1, vmax=1)

# %%
vehicles[vehicles_categorical].describe()
# Out:
#          ACCIDENT_NO VEHICLE_ID VEHICLE_MAKE VEHICLE_MODEL VEHICLE_TYPE_DESC  \
# count         328057     328057       309812        297334            328057
# unique        179868         21          641         12852                29
# top     T20160000627          A       TOYOTA        COMMOD               Car
# freq              21     179025        54258         13425            156717
#
#            LAMPS  LEVEL_OF_DAMAGE
# count   328056.0           328057
# unique       4.0                7
# top          2.0                1
# freq    267123.0            74360

# %%
vehicles[vehicles_numerical].describe()
# Out:
#        VEHICLE_YEAR_MANUF  VEHICLE_WEIGHT  SEATING_CAPACITY    TARE_WEIGHT  \
# count       321128.000000    40982.000000     271661.000000  316113.000000
# mean          1837.879475     5618.394027          5.035883    1554.931610
# std            559.044704     7315.242181          2.952170    1704.788442
# min              0.000000      251.000000          1.000000       0.000000
# 25%           2001.000000     2485.750000          5.000000    1100.000000
# 50%           2008.000000     2830.000000          5.000000    1400.000000
# 75%           2013.000000     3330.000000          5.000000    1675.000000
# max           3001.000000   340000.000000         74.000000   96000.000000
#
#        TOTAL_NO_OCCUPANTS  CARRY_CAPACITY
# count       328035.000000    40828.000000
# mean             1.246812     2488.205031
# std              0.842449     4462.318789
# min              0.000000        1.000000
# 25%              1.000000      710.000000
# 50%              1.000000     1035.000000
# 75%              1.000000     1380.000000
# max             96.000000   323060.000000

# %%
vehicles.VEHICLE_YEAR_MANUF.value_counts(normalize=True).sort_index(ascending=False) * 100
# Out:
# VEHICLE_YEAR_MANUF
# 3001.0    0.000311
# 2024.0    0.042662
# 2023.0    0.424130
# 2022.0    0.816185
# 2021.0    1.131013
#             ...
# 1913.0    0.000311
# 1910.0    0.000311
# 1909.0    0.000311
# 1900.0    0.062903
# 0.0       8.467340
# Name: proportion, Length: 104, dtype: float64

# %%
vehicles[['VEHICLE_WEIGHT','CARRY_CAPACITY', 'TARE_WEIGHT']]
# Out:
#         VEHICLE_WEIGHT  CARRY_CAPACITY  TARE_WEIGHT
# 0                  NaN             NaN       1350.0
# 1                  NaN             NaN       1600.0
# 2               1450.0           300.0       1150.0
# 3                  NaN             NaN       1300.0
# 4                  NaN             NaN       2250.0
# ...                ...             ...          ...
# 328052             NaN             NaN          0.0
# 328053             NaN             NaN          0.0
# 328054             NaN             NaN          0.0
# 328055          2505.0           877.0       1628.0
# 328056          1805.0           525.0       1280.0
#
# [328057 rows x 3 columns]

# %%
vehicles[vehicles.TARE_WEIGHT.isnull()]["VEHICLE_TYPE_DESC"].value_counts(normalize=True) * 100
# Out:
# VEHICLE_TYPE_DESC
# Motor Cycle                                           39.953115
# Bicycle                                               32.300737
# Not Known                                             10.423644
# Car                                                    7.811453
# Motor Scooter                                          2.670797
# Station Wagon                                          1.774950
# Tram                                                   1.105157
# Utility                                                0.979571
# Taxi                                                   0.611186
# Other Vehicle                                          0.611186
# Panel Van                                              0.410248
# Moped                                                  0.360013
# Bus/Coach                                              0.192565
# Train                                                  0.150703
# Prime Mover B-Double                                   0.108841
# Prime Mover - Single Trailer                           0.100469
# Quad Bike                                              0.100469
# Heavy Vehicle (Rigid) > 4.5 Tonnes                     0.092096
# Plant machinery and Agricultural equipment             0.083724
# Light Commercial Vehicle (Rigid) <= 4.5 Tonnes GVM     0.058607
# Parked trailers                                        0.033490
# Electric Device                                        0.025117
# Prime Mover Only                                       0.016745
# Not Applicable                                         0.008372
# Mini Bus(9-13 seats)                                   0.008372
# Horse (ridden or drawn)                                0.008372
# Name: proportion, dtype: float64

# %%
vehicle_type_with_no_null_tare_weight = vehicles.groupby('VEHICLE_TYPE_DESC')['TARE_WEIGHT'].count()
vehicle_type_with_null_tare_weight = vehicles[vehicles.TARE_WEIGHT.isnull()].VEHICLE_TYPE_DESC.value_counts()

percentage_of_null_tare_weight_all_vehicle_type = vehicle_type_with_null_tare_weight / (vehicle_type_with_no_null_tare_weight + vehicle_type_with_null_tare_weight) * 100

percentage_of_null_tare_weight_all_vehicle_type.sort_values(ascending=False)
# Out:
# VEHICLE_TYPE_DESC
# Moped                                                 36.440678
# Train                                                 29.508197
# Bicycle                                               21.290216
# Not Known                                             20.899782
# Motor Scooter                                         20.514469
# Motor Cycle                                           19.833749
# Tram                                                  18.750000
# Electric Device                                       16.666667
# Quad Bike                                              8.510638
# Other Vehicle                                          6.314879
# Not Applicable                                         5.263158
# Horse (ridden or drawn)                                4.166667
# Plant machinery and Agricultural equipment             3.367003
# Taxi                                                   2.515507
# Parked trailers                                        2.469136
# Prime Mover B-Double                                   1.666667
# Bus/Coach                                              1.581843
# Panel Van                                              0.670131
# Car                                                    0.595341
# Prime Mover - Single Trailer                           0.448430
# Utility                                                0.416355
# Station Wagon                                          0.325623
# Mini Bus(9-13 seats)                                   0.304878
# Heavy Vehicle (Rigid) > 4.5 Tonnes                     0.261656
# Prime Mover Only                                       0.242131
# Light Commercial Vehicle (Rigid) <= 4.5 Tonnes GVM     0.137741
# Prime Mover (No of Trailers Unknown)                        NaN
# Prime Mover B-Triple                                        NaN
# Rigid Truck(Weight Unknown)                                 NaN
# dtype: float64

# %%
for i in vehicles.VEHICLE_TYPE_DESC.unique():
    if vehicles[(vehicles.VEHICLE_TYPE_DESC == i)]['TARE_WEIGHT'].median() == 0:
        median_tare_weight = vehicles[(vehicles.VEHICLE_TYPE_DESC == i) & (vehicles.TARE_WEIGHT != 0)]['TARE_WEIGHT'].median()
    else:
        median_tare_weight = vehicles[(vehicles.VEHICLE_TYPE_DESC == i)]['TARE_WEIGHT'].median()
    print(f'{i}: {median_tare_weight}')
# Out:
# Car: 1300.0
# Station Wagon: 1622.0
# Taxi: 1560.0
# Bicycle: 15.0
# Motor Cycle: 178.0
# Utility: 1785.0
# Panel Van: 1752.0
# Prime Mover Only: 9180.0
# Heavy Vehicle (Rigid) > 4.5 Tonnes: 9390.0
# Not Known: 1632.5
# Light Commercial Vehicle (Rigid) <= 4.5 Tonnes GVM: 2700.0
# Prime Mover B-Double: 9300.0
# Other Vehicle: 2540.0
# Moped: 116.0
# Motor Scooter: 150.0
# Prime Mover - Single Trailer: 9086.0
# Tram: 3550.0
# Bus/Coach: 10780.0
# Mini Bus(9-13 seats): 2080.0
# Train: nan
# c:\Users\phucd\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\phucd\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Plant machinery and Agricultural equipment: 5800.0
# Not Applicable: 1745.0
# Quad Bike: 220.0
# Parked trailers: 988.5
# Prime Mover B-Triple: 9518.5
# Horse (ridden or drawn): nan
# Prime Mover (No of Trailers Unknown): 8820.0
# Rigid Truck(Weight Unknown): 5000.0
# Electric Device: nan
# c:\Users\phucd\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %%
for i in vehicles.VEHICLE_TYPE_DESC.unique():
    if vehicles[(vehicles.VEHICLE_TYPE_DESC == i)]['TARE_WEIGHT'].median() == 0:
        median_tare_weight = vehicles[(vehicles.VEHICLE_TYPE_DESC == i) & (vehicles.TARE_WEIGHT != 0)]['TARE_WEIGHT'].median()
    else:
        median_tare_weight = vehicles[(vehicles.VEHICLE_TYPE_DESC == i)]['TARE_WEIGHT'].median()
    vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].replace(0, median_tare_weight)
    vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].fillna(median_tare_weight)
# Out:
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].replace(0, median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].fillna(median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].replace(0, median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].fillna(median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].replace(0, median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].fillna(median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].replace(0, median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].fillna(median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].replace(0, median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].fillna(median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].replace(0, median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].fillna(median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].replace(0, median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].fillna(median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].replace(0, median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].fillna(median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].replace(0, median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].fillna(median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].replace(0, median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].fillna(median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].replace(0, median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].fillna(median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].replace(0, median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].fillna(median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].replace(0, median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].fillna(median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].replace(0, median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].fillna(median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].replace(0, median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].fillna(median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].replace(0, median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].fillna(median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].replace(0, median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].fillna(median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].replace(0, median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].fillna(median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].replace(0, median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].fillna(median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].replace(0, median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].fillna(median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].replace(0, median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].fillna(median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].replace(0, median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].fillna(median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].replace(0, median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].fillna(median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].replace(0, median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].fillna(median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].replace(0, median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].fillna(median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].replace(0, median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].fillna(median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].replace(0, median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].fillna(median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].replace(0, median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].fillna(median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].replace(0, median_tare_weight)
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3171693846.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['TARE_WEIGHT'] = vehicles['TARE_WEIGHT'].fillna(median_tare_weight)

# %%
vehicles[(vehicles.TARE_WEIGHT == 0) | (vehicles.TARE_WEIGHT.isnull())]
# Out:
#          ACCIDENT_NO VEHICLE_ID  VEHICLE_YEAR_MANUF VEHICLE_MAKE  \
# 14      T20120000050          A                 NaN          NaN
# 18      T20120000054          B              2007.0        H DAV
# 20      T20120000058          A                 NaN       YAMAHA
# 22      T20120000060          A              2008.0       SUZUKI
# 25      T20120000063          B                 NaN          NaN
# ...              ...        ...                 ...          ...
# 328043  T20250003243          B                 0.0         UNKN
# 328047  T20250003868          B                 0.0         UNKN
# 328052  T20250005328          A              2021.0        K T M
# 328053  T20250005503          A                 0.0          NaN
# 328054  T20250005503          B                 0.0         UNKN
#
#        VEHICLE_MODEL VEHICLE_TYPE_DESC  VEHICLE_WEIGHT  SEATING_CAPACITY  \
# 14               NaN           Bicycle             NaN               NaN
# 18            XL883L       Motor Cycle             NaN               NaN
# 20               NaN       Motor Cycle             NaN               NaN
# 22               VZR       Motor Cycle             NaN               NaN
# 25               NaN           Bicycle             NaN               NaN
# ...              ...               ...             ...               ...
# 328043           NaN         Not Known             NaN               NaN
# 328047           NaN               Car             NaN               NaN
# 328052        500EXC       Motor Cycle             NaN               NaN
# 328053           NaN           Bicycle             NaN               NaN
# 328054           NaN         Not Known             NaN               NaN
#
#         TARE_WEIGHT  TOTAL_NO_OCCUPANTS  CARRY_CAPACITY LAMPS LEVEL_OF_DAMAGE
# 14              NaN                 1.0             NaN   2.0               1
# 18              NaN                 1.0             NaN   2.0               1
# 20              NaN                 1.0             NaN   2.0               3
# 22              NaN                 1.0             NaN   2.0               1
# 25              NaN                 1.0             NaN   2.0               2
# ...             ...                 ...             ...   ...             ...
# 328043          0.0                 1.0             NaN   9.0               1
# 328047          0.0                 1.0             NaN   9.0               9
# 328052          0.0                 1.0             NaN   2.0               6
# 328053          0.0                 1.0             NaN   0.0               9
# 328054          0.0                 2.0             NaN   9.0               9
#
# [56978 rows x 13 columns]

# %%
vehicles[vehicles.VEHICLE_WEIGHT.isnull()].VEHICLE_TYPE_DESC.value_counts(normalize=True) * 100
# Out:
# VEHICLE_TYPE_DESC
# Car                                                   52.932857
# Station Wagon                                         20.948184
# Motor Cycle                                            8.380388
# Bicycle                                                6.312288
# Utility                                                4.034486
# Not Known                                              2.063921
# Panel Van                                              1.149525
# Taxi                                                   0.943307
# Prime Mover - Single Trailer                           0.842289
# Motor Scooter                                          0.541322
# Other Vehicle                                          0.339284
# Light Commercial Vehicle (Rigid) <= 4.5 Tonnes GVM     0.336497
# Prime Mover B-Double                                   0.256727
# Tram                                                   0.245232
# Prime Mover Only                                       0.243839
# Heavy Vehicle (Rigid) > 4.5 Tonnes                     0.108334
# Mini Bus(9-13 seats)                                   0.054341
# Bus/Coach                                              0.053296
# Quad Bike                                              0.043891
# Moped                                                  0.041104
# Prime Mover B-Triple                                   0.035879
# Plant machinery and Agricultural equipment             0.024036
# Train                                                  0.021249
# Parked trailers                                        0.016720
# Horse (ridden or drawn)                                0.008360
# Rigid Truck(Weight Unknown)                            0.006270
# Prime Mover (No of Trailers Unknown)                   0.006270
# Electric Device                                        0.006270
# Not Applicable                                         0.003832
# Name: proportion, dtype: float64

# %%
vehicles['VEHICLE_WEIGHT'] = vehicles['VEHICLE_WEIGHT'].fillna(vehicles.TARE_WEIGHT)
# Out:
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\3968964722.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['VEHICLE_WEIGHT'] = vehicles['VEHICLE_WEIGHT'].fillna(vehicles.TARE_WEIGHT)

# %%
vehicles['VEHICLE_WEIGHT'].isnull().sum()
# Out:
# np.int64(0)

# %%
vehicles['CARRY_CAPACITY'] = vehicles['CARRY_CAPACITY'].fillna(vehicles.VEHICLE_WEIGHT - vehicles.TARE_WEIGHT)
# Out:
# C:\Users\phucd\AppData\Local\Temp\ipykernel_11788\639928097.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['CARRY_CAPACITY'] = vehicles['CARRY_CAPACITY'].fillna(vehicles.VEHICLE_WEIGHT - vehicles.TARE_WEIGHT)

# %%
vehicles[['VEHICLE_WEIGHT','CARRY_CAPACITY', 'TARE_WEIGHT']]
# Out:
#         VEHICLE_WEIGHT  CARRY_CAPACITY  TARE_WEIGHT
# 0                  NaN             NaN       1350.0
# 1                  NaN             NaN       1600.0
# 2               1450.0           300.0       1150.0
# 3                  NaN             NaN       1300.0
# 4                  NaN             NaN       2250.0
# ...                ...             ...          ...
# 328052             NaN             NaN          0.0
# 328053             NaN             NaN          0.0
# 328054             NaN             NaN          0.0
# 328055          2505.0           877.0       1628.0
# 328056          1805.0           525.0       1280.0
#
# [328057 rows x 3 columns]

# %%
vehicles[vehicles.SEATING_CAPACITY.isnull()].VEHICLE_TYPE_DESC.value_counts(normalize=True) * 100
# Out:
# VEHICLE_TYPE_DESC
# Motor Cycle                                           41.749415
# Bicycle                                               32.131711
# Not Known                                             10.465281
# Car                                                    5.762820
# Motor Scooter                                          2.753741
# Other Vehicle                                          1.517838
# Tram                                                   1.248315
# Utility                                                0.911412
# Station Wagon                                          0.719909
# Panel Van                                              0.383006
# Prime Mover - Single Trailer                           0.333357
# Parked trailers                                        0.287254
# Taxi                                                   0.255337
# Heavy Vehicle (Rigid) > 4.5 Tonnes                     0.230513
# Moped                                                  0.205688
# Prime Mover B-Double                                   0.191503
# Bus/Coach                                              0.180864
# Light Commercial Vehicle (Rigid) <= 4.5 Tonnes GVM     0.122349
# Quad Bike                                              0.122349
# Prime Mover Only                                       0.122349
# Train                                                  0.108164
# Plant machinery and Agricultural equipment             0.060288
# Horse (ridden or drawn)                                0.042556
# Electric Device                                        0.031917
# Rigid Truck(Weight Unknown)                            0.028371
# Prime Mover (No of Trailers Unknown)                   0.010639
# Not Applicable                                         0.008866
# Prime Mover B-Triple                                   0.007093
# Mini Bus(9-13 seats)                                   0.007093
# Name: proportion, dtype: float64

# %%
vehicle_type_with_no_null_capacity = vehicles.groupby('VEHICLE_TYPE_DESC')['SEATING_CAPACITY'].count()
vehicle_type_with_null_capacity = vehicles[vehicles.SEATING_CAPACITY.isnull()].VEHICLE_TYPE_DESC.value_counts()

percentage_of_null_seating_capacity_all_vehicle_type = vehicle_type_with_null_capacity / (vehicle_type_with_no_null_capacity + vehicle_type_with_null_capacity) * 100

percentage_of_null_seating_capacity_all_vehicle_type.sort_values(ascending=False)
# Out:
# VEHICLE_TYPE_DESC
# Bicycle                                               100.000000
# Electric Device                                       100.000000
# Horse (ridden or drawn)                               100.000000
# Tram                                                  100.000000
# Parked trailers                                       100.000000
# Train                                                 100.000000
# Motor Scooter                                          99.871383
# Not Known                                              99.076716
# Moped                                                  98.305085
# Motor Cycle                                            97.859518
# Other Vehicle                                          74.048443
# Quad Bike                                              48.936170
# Rigid Truck(Weight Unknown)                            32.653061
# Not Applicable                                         26.315789
# Prime Mover (No of Trailers Unknown)                   26.086957
# Prime Mover B-Double                                   13.846154
# Plant machinery and Agricultural equipment             11.447811
# Prime Mover Only                                        8.353511
# Prime Mover - Single Trailer                            7.025411
# Bus/Coach                                               7.015131
# Taxi                                                    4.962095
# Prime Mover B-Triple                                    3.846154
# Heavy Vehicle (Rigid) > 4.5 Tonnes                      3.092293
# Panel Van                                               2.954048
# Car                                                     2.073802
# Utility                                                 1.829116
# Light Commercial Vehicle (Rigid) <= 4.5 Tonnes GVM      1.357733
# Mini Bus(9-13 seats)                                    1.219512
# Station Wagon                                           0.623598
# dtype: float64

# %%
accidents["HOUR"] = accidents["ACCIDENT_TIME"].apply(lambda x: x.hour)
hour_counts = accidents["HOUR"].value_counts().sort_index()

sns.lineplot(x=hour_counts.index, y=hour_counts.values)
plt.xlabel("Hour of the Day")
plt.ylabel("Number of Accidents")
plt.title("Accidents by Hour of the Day")

avg_accidents_by_hour = accidents['HOUR'].value_counts().mean()
plt.axhline(avg_accidents_by_hour, color='red', linestyle='dashed', linewidth=2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[562], line 1
# ----> 1 accidents["HOUR"] = accidents["ACCIDENT_TIME"].apply(lambda x: x.hour)
#       2 hour_counts = accidents["HOUR"].value_counts().sort_index()
#       4 sns.lineplot(x=hour_counts.index, y=hour_counts.values)
#
# File c:\Users\phucd\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Users\phucd\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\phucd\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\phucd\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\phucd\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[562], line 1, in <lambda>(x)
# ----> 1 accidents["HOUR"] = accidents["ACCIDENT_TIME"].apply(lambda x: x.hour)
#       2 hour_counts = accidents["HOUR"].value_counts().sort_index()
#       4 sns.lineplot(x=hour_counts.index, y=hour_counts.values)
#
# AttributeError: 'str' object has no attribute 'hour'

# %% [markdown]
# New dataset

# %%
person.head()
# Out:
#     ACCIDENT_NO PERSON_ID SEX AGE_GROUP INJ_LEVEL_DESC SEATING_POSITION  \
# 0  T20240013592         B   U   Unknown    Not injured                D
# 1  T20240013592         A   M     40-49   Other injury                D
# 2  T20210001147         B   M     30-39    Not injured                D
# 3  T20240001333        02   U   Unknown    Not injured               LF
# 4  T20240001333         A   M     30-39    Not injured                D
#
#    HELMET_BELT_WORN ROAD_USER_TYPE_DESC TAKEN_HOSPITAL
# 0               9.0             Drivers            NaN
# 1               1.0             Drivers              N
# 2               9.0             Drivers            NaN
# 3               9.0          Passengers            NaN
# 4               9.0             Drivers            NaN

# %%
person.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420320 entries, 0 to 420319
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ACCIDENT_NO          420320 non-null  object
#  1   PERSON_ID            420320 non-null  object
#  2   SEX                  420285 non-null  object
#  3   AGE_GROUP            420320 non-null  object
#  4   INJ_LEVEL_DESC       420320 non-null  object
#  5   SEATING_POSITION     403452 non-null  object
#  6   HELMET_BELT_WORN     420319 non-null  float64
#  7   ROAD_USER_TYPE_DESC  420320 non-null  object
#  8   TAKEN_HOSPITAL       149828 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 28.9+ MB

# %%
person['HELMET_BELT_WORN'] = person['HELMET_BELT_WORN'].astype('O')
# Out:
# C:\Users\phucd\AppData\Local\Temp\ipykernel_20804\3561666803.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   person['HELMET_BELT_WORN'] = person['HELMET_BELT_WORN'].astype('O')

# %%
(person.isnull().sum()/len(person) * 100).plot.bar()
# Out:
# <Axes: >

# %%
person[person['SEATING_POSITION'].isna()]['HELMET_BELT_WORN'].value_counts(normalize=True) * 100
# Out:
# HELMET_BELT_WORN
# 8.0    99.917003
# 9.0     0.077069
# 2.0     0.005928
# Name: proportion, dtype: float64

# %%
person[person['TAKEN_HOSPITAL'].isnull()]['INJ_LEVEL_DESC'].value_counts(normalize=True) * 100
# Out:
# INJ_LEVEL_DESC
# Not injured       68.513671
# Other injury      30.273723
# Fatality           0.615175
# Serious injury     0.597430
# Name: proportion, dtype: float64

# %%
person.duplicated().sum()
# Out:
# np.int64(0)

# %%
person.describe()
# Out:
#          ACCIDENT_NO PERSON_ID     SEX AGE_GROUP INJ_LEVEL_DESC  \
# count         420320    420320  420285    420320         420320
# unique        179877       116       3        14              4
# top     T20130018492         A       M     30-39    Not injured
# freq              97    175610  236145     75183         185967
#
#        SEATING_POSITION  HELMET_BELT_WORN ROAD_USER_TYPE_DESC TAKEN_HOSPITAL
# count            403452          420319.0              420320         149828
# unique               10               9.0                   8              2
# top                   D               1.0             Drivers              N
# freq             310257          229862.0              266172          75383

# %%
column = ['SEX', 'AGE_GROUP', 'INJ_LEVEL_DESC',
       'SEATING_POSITION', 'HELMET_BELT_WORN', 'ROAD_USER_TYPE_DESC',
       'TAKEN_HOSPITAL']

fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(15, 15))  # adjust rows/cols as needed
axes = axes.flatten()  # flatten to 1D array for easy looping

# Plot each column as bar chart
for i, col in enumerate(column):
    person[col].value_counts().sort_index().plot.bar(ax=axes[i])
    axes[i].set_title(f"{col}")
    axes[i].set_xlabel("Value")
    axes[i].set_ylabel("Count")

# Hide any unused axes if columns < subplot cells
for j in range(len(column), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
location.head()
# Out:
#     ACCIDENT_NO   ROAD_NAME ROAD_TYPE ROAD_NAME_INT ROAD_TYPE_INT
# 0  T20120000021     WILLIAM      ROAD      HARLEIAN        STREET
# 1  T20120000139     PRINCES    STREET     RATHDOWNE        STREET
# 2  T20120000142       WELLS      ROAD   ROYAL PALMS           NaN
# 3  T20120000148      HOWQUA     TRACK   THREE CHAIN         TRACK
# 4  T20120000155  TOURMALINE  CRESCENT       WHALLEY         DRIVE

# %%
location.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179877 entries, 0 to 179876
# Data columns (total 5 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   ACCIDENT_NO    179877 non-null  object
#  1   ROAD_NAME      179657 non-null  object
#  2   ROAD_TYPE      177527 non-null  object
#  3   ROAD_NAME_INT  179186 non-null  object
#  4   ROAD_TYPE_INT  177705 non-null  object
# dtypes: object(5)
# memory usage: 6.9+ MB

# %%
(location.isnull().sum()/len(location) * 100).plot.bar()
# Out:
# <Axes: >

# %%
node.head()
# Out:
#     ACCIDENT_NO        AMG_X        AMG_Y   LGA_NAME LGA NAME ALL  \
# 0  T20120028741  2497568.320  2409445.265  MELBOURNE    MELBOURNE
# 1  T20120001763  2497122.206  2409527.753  MELBOURNE    MELBOURNE
# 2  T20120028741  2497568.320  2409445.265  MELBOURNE    MELBOURNE
# 3  T20140002916  2497475.110  2409905.366  MELBOURNE    MELBOURNE
# 4  T20120009149  2496252.604  2411020.384  MELBOURNE    MELBOURNE
#
#   DEG_URBAN_NAME   LATITUDE   LONGITUDE  POSTCODE_CRASH
# 0     MELB_URBAN -37.816010  144.972382            3000
# 1  MELBOURNE_CBD -37.815265  144.967316            3000
# 2  MELBOURNE_CBD -37.816010  144.972382            3000
# 3  MELBOURNE_CBD -37.811864  144.971325            3000
# 4     MELB_URBAN -37.801813  144.957447            3000

# %%
node.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182633 entries, 0 to 182632
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   ACCIDENT_NO     182633 non-null  object
#  1   AMG_X           182633 non-null  float64
#  2   AMG_Y           182633 non-null  float64
#  3   LGA_NAME        182633 non-null  object
#  4   LGA NAME ALL    182632 non-null  object
#  5   DEG_URBAN_NAME  181730 non-null  object
#  6   LATITUDE        182633 non-null  float64
#  7   LONGITUDE       182633 non-null  float64
#  8   POSTCODE_CRASH  182633 non-null  int64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 12.5+ MB

# %%
(node.isnull().sum() / len(node) * 100).plot.bar()
# Out:
# <Axes: >

# %%
node.hist(figsize=(15,10))
plt.show()

# %%
node.columns
# Out:
# Index(['ACCIDENT_NO', 'AMG_X', 'AMG_Y', 'LGA_NAME', 'LGA NAME ALL',
#        'DEG_URBAN_NAME', 'LATITUDE', 'LONGITUDE', 'POSTCODE_CRASH'],
#       dtype='object')

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(20,10))
axes = axes.flatten()

categorical_cols = ['LGA_NAME', 'LGA NAME ALL', 'DEG_URBAN_NAME', 'POSTCODE_CRASH']

for i, col in enumerate(categorical_cols):
    node[col].value_counts().sort_values(ascending=True).tail(10).plot.barh(ax=axes[i], color='green')
    axes[i].set_title(f"Top 10 {col}")

plt.tight_layout()
plt.show()

# %% [markdown]
# Data Preparation

# %%
ax = sns.countplot(data=accidents, x="DAY_WEEK_DESC", order=["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"], color='orange')
plt.xticks(rotation=45)
plt.xlabel("Week Day")
plt.ylabel("Number of Accidents")
plt.title("Accidents by Day of Week")
ax.bar_label(ax.containers[0])

avg_accidents_by_type = accidents["DAY_WEEK_DESC"].value_counts().mean()
plt.axhline(avg_accidents_by_type, color='red', linestyle='dashed', linewidth=2)

# %%
ax = sns.countplot(data=accidents, y='ACCIDENT_TYPE_DESC', orient='h')
plt.xlabel("Number of Accidents")
plt.ylabel("Type of Accident")
plt.title("Accidents by Type")
# Out:
# Text(0.5, 1.0, 'Accidents by Type')

# %%
ax = sns.countplot(data=accidents, x='LIGHT_CONDITION')
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '120042'),
#  Text(0, 0, '15488'),
#  Text(0, 0, '27620'),
#  Text(0, 0, '394'),
#  Text(0, 0, '9524'),
#  Text(0, 0, '2028'),
#  Text(0, 0, '4781')]

# %%
sns.violinplot(data=accidents, x="SEVERITY", y="LIGHT_CONDITION")
# Out:
# <Axes: xlabel='SEVERITY', ylabel='LIGHT_CONDITION'>

# %%
data=accidents.groupby("LIGHT_CONDITION")["SEVERITY"].value_counts(normalize=True).mul(100).reset_index(name='Percentage')
sns.barplot(data=data, x='LIGHT_CONDITION', y='Percentage', hue='SEVERITY')
# Out:
# <Axes: xlabel='LIGHT_CONDITION', ylabel='Percentage'>

# %%
sns.violinplot(x="SPEED_ZONE", y="SEVERITY", data=accidents)
plt.show()

# %%
ax = sns.countplot(x=accidents["NO_OF_VEHICLES"])
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '5'),
#  Text(0, 0, '58546'),
#  Text(0, 0, '101316'),
#  Text(0, 0, '15126'),
#  Text(0, 0, '3603'),
#  Text(0, 0, '901'),
#  Text(0, 0, '235'),
#  Text(0, 0, '83'),
#  Text(0, 0, '30'),
#  Text(0, 0, '10'),
#  Text(0, 0, '9'),
#  Text(0, 0, '3'),
#  Text(0, 0, '4'),
#  Text(0, 0, '2'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1')]

# %%
accidents['SPEED_ZONE'].value_counts().plot.barh()
# Out:
# <Axes: ylabel='SPEED_ZONE'>

# %%
vehicles.head()
# Out:
#     ACCIDENT_NO  VEHICLE_YEAR_MANUF ROAD_SURFACE_TYPE_DESC VEHICLE_MAKE  \
# 0  T20120000009              1996.0                  Paved       HOLDEN
# 1  T20120000012              2002.0                  Paved       HOLDEN
# 2  T20120000012              1988.0                  Paved       TOYOTA
# 3  T20120000013              1997.0                  Paved       MITSUB
# 4  T20120000013              2010.0                  Paved       TOYOTA
#
#   VEHICLE_MODEL  TOTAL_NO_OCCUPANTS  LAMPS  LEVEL_OF_DAMAGE
# 0        ACCLAI                 2.0    1.0                5
# 1        MONARO                 2.0    1.0                2
# 2           NaN                 1.0    9.0                4
# 3         MAGNA                 1.0    1.0                4
# 4           NaN                 0.0    2.0                4

# %%
vehicles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 328057 entries, 0 to 328056
# Data columns (total 17 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ACCIDENT_NO         328057 non-null  object
#  1   VEHICLE_ID          328057 non-null  object
#  2   VEHICLE_YEAR_MANUF  321128 non-null  float64
#  3   VEHICLE_MAKE        309812 non-null  object
#  4   VEHICLE_MODEL       297334 non-null  object
#  5   VEHICLE_POWER       0 non-null       float64
#  6   VEHICLE_TYPE_DESC   328057 non-null  object
#  7   VEHICLE_WEIGHT      40982 non-null   float64
#  8   NO_OF_WHEELS        286850 non-null  float64
#  9   NO_OF_CYLINDERS     294100 non-null  float64
#  10  SEATING_CAPACITY    271661 non-null  float64
#  11  TARE_WEIGHT         316113 non-null  float64
#  12  TOTAL_NO_OCCUPANTS  328035 non-null  float64
#  13  CARRY_CAPACITY      40828 non-null   float64
#  14  CUBIC_CAPACITY      45409 non-null   float64
#  15  LAMPS               328056 non-null  float64
#  16  LEVEL_OF_DAMAGE     328057 non-null  int64
# dtypes: float64(11), int64(1), object(5)
# memory usage: 42.5+ MB

# %%
person.describe()
# Out:
#          ACCIDENT_NO     SEX AGE_GROUP INJ_LEVEL_DESC SEATING_POSITION  \
# count         420320  420285    420320         420320           403452
# unique        179877       3        14              4               10
# top     T20130018492       M     30-39    Not injured                D
# freq              97  236145     75183         185967           310257
#
#         HELMET_BELT_WORN ROAD_USER_TYPE_DESC TAKEN_HOSPITAL
# count           420319.0              420320         149828
# unique               9.0                   8              2
# top                  1.0             Drivers              N
# freq            229862.0              266172          75383

# %%
person.isnull().sum()
# Out:
# ACCIDENT_NO                 0
# SEX                        35
# AGE_GROUP                   0
# INJ_LEVEL_DESC              0
# SEATING_POSITION        16868
# HELMET_BELT_WORN            1
# ROAD_USER_TYPE_DESC         0
# TAKEN_HOSPITAL         270492
# dtype: int64

# %%
accidents.hist(figsize=(10,15))
# Out:
# array([[<Axes: title={'center': 'LIGHT_CONDITION'}>,
#         <Axes: title={'center': 'NO_OF_VEHICLES'}>,
#         <Axes: title={'center': 'NO_PERSONS_KILLED'}>],
#        [<Axes: title={'center': 'NO_PERSONS_INJ_2'}>,
#         <Axes: title={'center': 'NO_PERSONS_INJ_3'}>,
#         <Axes: title={'center': 'NO_PERSONS_NOT_INJ'}>],
#        [<Axes: title={'center': 'NO_PERSONS'}>,
#         <Axes: title={'center': 'POLICE_ATTEND'}>,
#         <Axes: title={'center': 'SEVERITY'}>],
#        [<Axes: title={'center': 'SPEED_ZONE'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
vehicles[vehicles['VEHICLE_YEAR_MANUF'] < 1900]
# Out:
#          ACCIDENT_NO  VEHICLE_YEAR_MANUF ROAD_SURFACE_TYPE_DESC VEHICLE_MAKE  \
# 130     T20120000258                 0.0                  Paved          NaN
# 215     T20120000422                 0.0                  Paved          NaN
# 251     T20120000458                 0.0                  Paved       TOYOTA
# 336     T20120000615                 0.0                  Paved       HOLDEN
# 337     T20120000615                 0.0                  Paved          NaN
# ...              ...                 ...                    ...          ...
# 328042  T20250003243                 0.0                  Paved         UNKN
# 328043  T20250003243                 0.0                  Paved         UNKN
# 328047  T20250003868                 0.0                  Paved         UNKN
# 328053  T20250005503                 0.0                  Paved          NaN
# 328054  T20250005503                 0.0                  Paved         UNKN
#
#        VEHICLE_MODEL  TOTAL_NO_OCCUPANTS  LAMPS  LEVEL_OF_DAMAGE
# 130              NaN                 1.0    2.0                1
# 215              NaN                 1.0    2.0                6
# 251           COROLL                 1.0    2.0                5
# 336              NaN                 1.0    9.0                9
# 337              NaN                 1.0    2.0                2
# ...              ...                 ...    ...              ...
# 328042           NaN                 1.0    9.0                1
# 328043           NaN                 1.0    9.0                1
# 328047           NaN                 1.0    9.0                9
# 328053           NaN                 1.0    0.0                9
# 328054           NaN                 2.0    9.0                9
#
# [27191 rows x 8 columns]

# %%
person.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420320 entries, 0 to 420319
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ACCIDENT_NO          420320 non-null  object
#  1   SEX                  420285 non-null  object
#  2   AGE_GROUP            420320 non-null  object
#  3   INJ_LEVEL_DESC       420320 non-null  object
#  4   SEATING_POSITION     403452 non-null  object
#  5   HELMET_BELT_WORN     420319 non-null  object
#  6   ROAD_USER_TYPE_DESC  420320 non-null  object
#  7   TAKEN_HOSPITAL       149828 non-null  object
# dtypes: object(8)
# memory usage: 25.7+ MB
